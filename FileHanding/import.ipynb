# %%
from math import sqrt,pi

print(sqrt(100))
print(pi)
# Out:
# 10.0
# 3.141592653589793

# %%
import numpy as np

np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from Packages.maths import addition

addition(2,3)
# Out:
# 5
