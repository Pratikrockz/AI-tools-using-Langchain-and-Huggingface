# %%
import random

random .randint(1,10)
# Out:
# 9

# %%
import random

random.choice(["Apple","Banana","Guava"])
# Out:
# 'Guava'

# %%
## File handling

import os

print(os.getcwd())

os.mkdir('_test')
# Out:
# c:\Users\ACER\OneDrive\Desktop\GenAi project\BasicPython

# %%
## high level file handling

import shutil

shutil.copyfile('sample.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data serialisation

import json

data={"name":"pratik","age":"26"}


json_str=json.dumps(data)

print(json_str)

print(type(json_str))


revert_data=json.loads(json_str)

print(revert_data)

print(type(revert_data))
# Out:
# {"name": "pratik", "age": "26"}
# <class 'str'>
# {'name': 'pratik', 'age': '26'}
# <class 'dict'>

# %%
## Creating csv and read

import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['name','age'])


with open('example.csv',mode='r') as file:
    reader=csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['name', 'age']

# %%
### Time stamp 

from datetime import datetime ,timedelta

now = datetime.now()

print(now)

yeasterday= now - timedelta(days=1)

print(yeasterday)
# Out:
# 2026-06-29 00:07:05.385571
# 2026-06-28 00:07:05.385571

# %%
import time

print(time.time())


time.sleep(2)

print(time.time())
# Out:
# 1782672119.836326
# 1782672121.8370934

# %%
## Regukar expression

import re

patern =r'\d+'

text="I am pratik 2026"

match=re.search(patern,text)

print(match.group())
# Out:
# 2026
