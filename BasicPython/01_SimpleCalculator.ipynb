# %%
# Simple Calculator

# %%
first_val=float(input("Please input first value "))
second_val = float(input("Please input second value "))

# %%
print("This is sum",first_val+second_val)
print("This is difference",first_val-second_val)
print("This is multiply",first_val*second_val)
print("This is dividedValue",first_val/second_val)
# Out:
# This is sum 36.0
# This is difference -10.0
# This is multiply 299.0
# This is dividedValue 0.5652173913043478
