# %%
numbers=[1,"A",2,3,4,"B"]

print(numbers[2])
print(numbers[0:3])
# Out:
# 2
# [1, 'A', 2]

# %%
numbers[1]="Z"
print(numbers)
# Out:
# [1, 'Z', 2, 3, 4, 'B']

# %%
numbers.append("banana")
numbers.insert (1,"guava")
print(numbers)
# Out:
# [1, 'guava', 'Z', 2, 3, 4, 'B', 'banana']

# %%
numbers.pop()
print(numbers)
# Out:
# [1, 'guava', 'Z', 2, 3, 4, 'B']

# %%
print(numbers.index("guava"))
numbers.insert(1,"guava")
print(numbers.count("guava"))
# Out:
# 1
# 2

# %%
numbers=["a","t","e"]
numbers.sort()
print(numbers)
# Out:
# ['a', 'e', 't']

# %%
numbers.reverse()
print(numbers)
# Out:
# ['t', 'e', 'a']

# %%
numbers.clear()
print(numbers)
# Out:
# []
